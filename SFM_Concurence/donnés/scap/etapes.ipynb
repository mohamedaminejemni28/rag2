# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd

def analyse_concurrent(nom):
    fake_database = {
        "Telecom Tunisie": {
            "Produits": "Internet haut débit, VoIP, Cloud",
            "Effectifs": 350,
            "Forces": "Couverture nationale, support 24/7",
            "Faiblesses": "Prix un peu élevés"
        },
        "AfricTel Solutions": {
            "Produits": "Solutions mobiles, Fibre optique",
            "Effectifs": 220,
            "Forces": "Innovations mobiles, tarifs compétitifs",
            "Faiblesses": "Présence limitée hors grandes villes"
        },
        "NetConnect Afrique": {
            "Produits": "Internet satellite, VPN",
            "Effectifs": 150,
            "Forces": "Présence en zones rurales, sécurité renforcée",
            "Faiblesses": "Débit variable selon zones"
        },
        "Réseaux Innovants": {
            "Produits": "Services IT, intégration réseaux",
            "Effectifs": 100,
            "Forces": "Expertise IT, solutions personnalisées",
            "Faiblesses": "Moins connu sur le marché télécom"
        },
        "Global Telecom Services": {
            "Produits": "Téléphonie fixe, Data center",
            "Effectifs": 400,
            "Forces": "Infrastructure robuste, large clientèle",
            "Faiblesses": "Moins flexible sur les offres"
        }
    }
    
    return {
        "Nom": nom,
        "Produits": fake_database[nom]["Produits"],
        "Effectifs": fake_database[nom]["Effectifs"],
        "Forces": fake_database[nom]["Forces"],
        "Faiblesses": fake_database[nom]["Faiblesses"]
    }

# Liste fictive
concurrents = [
    "Telecom Tunisie",
    "AfricTel Solutions",
    "NetConnect Afrique",
    "Réseaux Innovants",
    "Global Telecom Services"
]

resultats = []
for concurrent in concurrents:
    data = analyse_concurrent(concurrent)
    resultats.append(data)

df = pd.DataFrame(resultats)
df.head()
# Out:
#                        Nom                          Produits  Effectifs  \
# 0          Telecom Tunisie  Internet haut débit, VoIP, Cloud        350
# 1       AfricTel Solutions  Solutions mobiles, Fibre optique        220
# 2       NetConnect Afrique           Internet satellite, VPN        150
# 3        Réseaux Innovants  Services IT, intégration réseaux        100
# 4  Global Telecom Services      Téléphonie fixe, Data center        400
#
#                                           Forces  \
# 0             Couverture nationale, support 24/7
# 1        Innovations mobiles, tarifs compétitifs
# 2  Présence en zones rurales, sécurité renforcée
# 3         Expertise IT, solutions personnalisées
# 4        Infrastructure robuste, large clientèle
#
#                              Faiblesses
# 0                    Prix un peu élevés
# 1  Présence limitée hors grandes villes
# 2            Débit variable selon zones
# 3     Moins connu sur le marché télécom
# ...
