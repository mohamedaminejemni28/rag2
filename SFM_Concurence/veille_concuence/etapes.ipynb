# %% [markdown]
# 🔹 1. Compréhension des données
# Analyse le fichier Excel pour bien comprendre les colonnes :
#
# Nom du concurrent
#
# Type de service offert
#
# Tarif proposé
#
# Présence ou non d'une offre spéciale

# %% [markdown]
# ----------------------------------------------------------------------------
# 2. Définition des fonctionnalités du sous-agent
# Décide des actions que cet agent devra pouvoir réaliser, par exemple :
#
# Afficher les concurrents par service
#
# Comparer les prix (min, max, moyenne) pour chaque service
#
# Identifier les offres spéciales en cours
#
# Repérer les concurrents les moins chers
#
# Générer un résumé du marché par service

# %% [markdown]
# -------------------------------------------------------------------------
# 3. Organisation des fonctions internes
# Structure l’agent autour de fonctions :
#
# Une fonction par tâche précise
#
# Chaque fonction travaille sur une feuille Excel et renvoie un résultat prêt à afficher ou traiter

# %% [markdown]
#  ------------------------------------------------------------------
#  4. Création d'une API pour exposer les fonctionnalités
# Prévois un système d’API (par exemple avec FastAPI) qui permet à d'autres agents (ou à l'agent master) de consommer les résultats du sous-agent

# %% [markdown]
# -------------------------------------------------------------------
# 5. Conception modulaire
# Chaque tâche doit être indépendante
#
# Le module doit pouvoir être remplacé ou utilisé ailleurs sans dépendances fortes

# %% [markdown]
# ---------------------------------------------------
# 6. Création de tests unitaires
# Rédige des tests simples pour vérifier que :
#
# Les tarifs sont bien filtrés
#
# Les résultats sont cohérents (pas de doublons, bons types, etc.)
#
# Aucune donnée manquante n’empêche le fonctionnement

# %% [markdown]
# --------------------------
# .7 Préparation d’une documentation
# Documente :
#
# Les entrées attendues (données Excel, colonnes)
#
# Les fonctionnalités disponibles
#
# Les cas d’usage possibles
#
# Comment appeler l’agent depuis l’agent master

# %% [markdown]
# ------------------------
#  8. Intégration avec l’Agent Master
# Prévois une interface claire pour que l’agent master puisse appeler ce sous-agent en fonction des besoins de l’utilisateur final (ex : “Montre-moi les concurrents en cybersécurité avec offres spéciales”)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
